# %%
import requests

url = 'http://apis.data.go.kr/B500001/rwis/waterFlux/waterFlux'
params ={'serviceKey' : 'h7uVdRcT/R8AJ75m8eAiLtoVwLl4MNWar3Miu+926WzOCe+ftmeX2FyFwEF+tT1oYcPX3gmZFNmoJ5qBkGh7Sw==', 'sujCode' : '318', 'stDt' : '2022-01-01', 'stTm' : '00', 'edDt' : '2022-12-31', 'edTm' : '24', 'pageNo' : '1', 'numOfRows' : '10', 'fcltyMngNo' : '4148012318','_type':'json' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE."},"body":{"items":{"item":[{"dataItemDesc":"\xea\xb3\xa0\xec\x96\x91 \xed\x8c\x8c\xec\xa3\xbc(\xec\xa0\x95) \xec\xa0\x95\xec\x88\x98 \xec\x9c\xa0\xec\xb6\x9c \xec\x9c\xa0\xeb\x9f\x89 \xec\xa0\x81\xec\x82\xb0\xec\xb0\xa8","dataItemDiv":"D","dataItemTagsn":19166,"dataVal":385,"fcltyMngNo":4148012318,"fcltyNm":"\xed\x8c\x8c\xec\xa3\xbc\xec\xa0\x95\xec\x88\x98\xec\x9e\xa5","itemUnit":"\xe3\x8e\xa5","no":17494,"occrrncDt":2022123124},{"dataItemDesc":"\xed\x8c\x8c\xec\xa3\xbc(\xec\xa0\x95) \xec\x9b\x90\xec\x88\x98 \xec\x9c\xa0\xec\x9e\x85\xec\x9c\xa0\xeb\x9f\x89","dataItemDiv":"M","dataItemTagsn":44381,"dataVal":"2,793","fcltyMngNo":4148012318,"fcltyNm":"\xed\x8c\x8c\xec\xa3\xbc\xec\xa0\x95\xec\x88\x98\xec\x9e\xa5","itemUnit":"\xe3\x8e\xa5\\/h","no":17493,"occrrncDt":2022123124},{"dataItemDesc":"\xea\xb3\xa0\xec\x96\x91 \xed\x8c\x8c\xec\xa3\xbc(\xec\xa0\x95) \xec\xa0\x95\xec\x88\x98 \xec\x9c\xa0\xec\xb6\x9c \xec\x9c\xa
# ...

# %%
import json
df = json.loads(str(response.content,'utf-8'))

# %%
df
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'dataItemDesc': '고양 파주(정) 정수 유출 유량 적산차',
#       'dataItemDiv': 'D',
#       'dataItemTagsn': 19166,
#       'dataVal': 385,
#       'fcltyMngNo': 4148012318,
#       'fcltyNm': '파주정수장',
#       'itemUnit': '㎥',
#       'no': 17494,
#       'occrrncDt': 2022123124},
#      {'dataItemDesc': '파주(정) 원수 유입유량',
#       'dataItemDiv': 'M',
#       'dataItemTagsn': 44381,
#       'dataVal': '2,793',
#       'fcltyMngNo': 4148012318,
#       'fcltyNm': '파주정수장',
#       'itemUnit': '㎥/h',
#       'no': 17493,
#       'occrrncDt': 2022123124},
#      {'dataItemDesc': '고양 파주(정) 정수 유출 유량 적산차',
#       'dataItemDiv': 'D',
#       'dataItemTagsn': 19166,
#       'dataVal': 358,
#       'fcltyMngNo': 4148012318,
#       'fcltyNm': '파주정수장',
#       'itemUnit': '㎥',
#       'no': 17492,
#       'occrrncDt': 2022123123},
#      {'dataItemDesc': '파주(정) 원수 유입유량',
#       'dataItemDiv': 'M',
# ...

# %%
df['response']['body']['items']['item']
# Out:
# [{'dataItemDesc': '고양 파주(정) 정수 유출 유량 적산차',
#   'dataItemDiv': 'D',
#   'dataItemTagsn': 19166,
#   'dataVal': 385,
#   'fcltyMngNo': 4148012318,
#   'fcltyNm': '파주정수장',
#   'itemUnit': '㎥',
#   'no': 17494,
#   'occrrncDt': 2022123124},
#  {'dataItemDesc': '파주(정) 원수 유입유량',
#   'dataItemDiv': 'M',
#   'dataItemTagsn': 44381,
#   'dataVal': '2,793',
#   'fcltyMngNo': 4148012318,
#   'fcltyNm': '파주정수장',
#   'itemUnit': '㎥/h',
#   'no': 17493,
#   'occrrncDt': 2022123124},
#  {'dataItemDesc': '고양 파주(정) 정수 유출 유량 적산차',
#   'dataItemDiv': 'D',
#   'dataItemTagsn': 19166,
#   'dataVal': 358,
#   'fcltyMngNo': 4148012318,
#   'fcltyNm': '파주정수장',
#   'itemUnit': '㎥',
#   'no': 17492,
#   'occrrncDt': 2022123123},
#  {'dataItemDesc': '파주(정) 원수 유입유량',
#   'dataItemDiv': 'M',
#   'dataItemTagsn': 44381,
#   'dataVal': '3,703',
#   'fcltyMngNo': 4148012318,
#   'fcltyNm': '파주정수장',
#   'itemUnit': '㎥/h',
#   'no': 17491,
#   'occrrncDt': 2022123123},
#  {'dataItemDesc': '고양 파주(정) 정수 유출 유량 적산차',
# ...
